# %%
import imageio
import matplotlib
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

from torchvision.utils import make_grid, save_image
import torchvision.datasets as datasets
import torchvision.transforms as transforms


matplotlib.style.use("ggplot")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 512
epochs = 200
sample_size = 64
nz = 128
k = 1

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]
)
train_dataset = datasets.MNIST(
    root="data", train=True, transform=transform, download=True
)
train_loader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, num_workers=4
)

# %%
class Generator(nn.Module):
    def __init__(self, nz):
        super().__init__()
        self.nz = nz
        self.main = nn.Sequential(
            nn.Linear(self.nz, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 784),
            nn.Tanh(),
        )

    def forward(self, x):
        return self.main(x).view(-1, 1, 28, 28)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.n_input = 784
        self.main = nn.Sequential(
            nn.Linear(self.n_input, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        x = x.view(-1, 784)
        return self.main(x)

# %%
generator = Generator(nz).to(device)
discriminator = Discriminator().to(device)
print(generator)
print(discriminator)
# Out:
# Generator(
#   (main): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.2)
#     (4): Linear(in_features=512, out_features=1024, bias=True)
#     (5): LeakyReLU(negative_slope=0.2)
#     (6): Linear(in_features=1024, out_features=784, bias=True)
#     (7): Tanh()
#   )
# )
# Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Dropout(p=0.3, inplace=False)
#     (9): Linear(in_features=256, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )

# %%
optim_g = optim.Adam(generator.parameters(), lr=0.0002)
optim_d = optim.Adam(discriminator.parameters(), lr=0.0002)

criterion = nn.BCELoss()

losses_g = []
losses_d = []
images = []

# %%
def save_generator_image(image, path):
    save_image(image, path)

# %%
def train_discriminator(optimizer, data_real, data_fake):
    b_size = data_real.size(0)
    real_label = torch.ones(b_size, 1).to(device)
    fake_label = torch.zeros(b_size, 1).to(device)
    optimizer.zero_grad()
    output_real = discriminator(data_real)
    loss_real = criterion(output_real, real_label)
    output_fake = discriminator(data_fake)
    loss_fake = criterion(output_fake, fake_label)
    loss_real.backward()
    loss_fake.backward()
    optimizer.step()
    return loss_real + loss_fake

# %%
def train_generator(optimizer, data_fake):
    b_size = data_fake.size(0)
    real_label = torch.ones(b_size, 1).to(device)
    optimizer.zero_grad()
    output = discriminator(data_fake)
    loss = criterion(output, real_label)
    loss.backward()
    optimizer.step()
    return loss

# %%
generator.train()
discriminator.train()

for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    idxh = 0
    for idx, data in enumerate(train_loader):
        image, _ = data
        image = image.to(device)
        b_size = len(image)
        for step in range(k):
            data_fake = generator(torch.randn(b_size, nz).to(device).detach())
            data_real = image
            loss_d += train_discriminator(optim_d, image, data_fake)
        data_fake = generator(torch.randn(b_size, nz).to(device).detach())
        loss_g += train_generator(optim_g, data_fake)
        idxh = idx

    generated_image = generator(torch.randn(sample_size, nz).to(device)).cpu().detach()
    generated_image = make_grid(generated_image)
    save_generator_image(generated_image, f"../pytorch/data/generated_images_{epoch}.png")
    images.append(generated_image)
    epoch_loss_g = loss_g / idxh
    epoch_loss_d = loss_d / idxh
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)

    print(f"Epoch {epoch} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")
# Out:
# Epoch 0 of 200
# Generator loss: 1.22164702, Discriminator loss: 0.99904460
# Epoch 1 of 200
# Generator loss: 1.83263886, Discriminator loss: 1.07312822
# Epoch 2 of 200
# Generator loss: 5.51242971, Discriminator loss: 0.53172719
# Epoch 3 of 200
# Generator loss: 5.83960152, Discriminator loss: 0.40303272
# Epoch 4 of 200
# Generator loss: 6.19271708, Discriminator loss: 0.64730644
# Epoch 5 of 200
# Generator loss: 3.85149670, Discriminator loss: 0.79881114
# Epoch 6 of 200
# Generator loss: 3.72132826, Discriminator loss: 0.85485297
# Epoch 7 of 200
# Generator loss: 3.19053173, Discriminator loss: 0.88970071
# Epoch 8 of 200
# Generator loss: 2.02333879, Discriminator loss: 1.04996240
# Epoch 9 of 200
# Generator loss: 1.71920097, Discriminator loss: 0.84401453
# Epoch 10 of 200
# Generator loss: 2.55997682, Discriminator loss: 0.74866498
# Epoch 11 of 200
# Generator loss: 4.18465185, Discriminator loss: 0.73863113
# Epoch 12 of 200
# Generator loss: 2.89535832, Discriminator loss: 0.81312317
# Epoch 13 of 200
# Generator loss: 2.15694213, Discriminator loss: 0.95888495
# Epoch 14 of 200
# Generator loss: 2.66742635, Discriminator loss: 0.74681598
# Epoch 15 of 200
# Generator loss: 3.37009382, Discriminator loss: 0.69183445
# Epoch 16 of 200
# Generator loss: 3.43011832, Discriminator loss: 0.61734658
# Epoch 17 of 200
# Generator loss: 3.01483536, Discriminator loss: 0.73504144
# Epoch 18 of 200
# Generator loss: 3.81116104, Discriminator loss: 0.59032828
# Epoch 19 of 200
# Generator loss: 3.41785169, Discriminator loss: 0.53689831
# Epoch 20 of 200
# Generator loss: 3.15996790, Discriminator loss: 0.62101895
# Epoch 21 of 200
# Generator loss: 2.95963764, Discriminator loss: 0.51752782
# Epoch 22 of 200
# Generator loss: 3.98001790, Discriminator loss: 0.33601090
# Epoch 23 of 200
# Generator loss: 3.35319781, Discriminator loss: 0.45705679
# Epoch 24 of 200
# Generator loss: 3.69176435, Discriminator loss: 0.45830029
# Epoch 25 of 200
# Generator loss: 3.05560207, Discriminator loss: 0.40559196
# Epoch 26 of 200
# Generator loss: 3.34166956, Discriminator loss: 0.44144040
# Epoch 27 of 200
# Generator loss: 3.85191131, Discriminator loss: 0.35195795
# Epoch 28 of 200
# Generator loss: 3.83511591, Discriminator loss: 0.27755806
# Epoch 29 of 200
# Generator loss: 3.81656814, Discriminator loss: 0.42456713
# Epoch 30 of 200
# Generator loss: 3.55205011, Discriminator loss: 0.40563342
# Epoch 31 of 200
# Generator loss: 3.69538856, Discriminator loss: 0.31073529
# Epoch 32 of 200
# Generator loss: 3.49426889, Discriminator loss: 0.38543233
# Epoch 33 of 200
# Generator loss: 3.78634906, Discriminator loss: 0.38532418
# Epoch 34 of 200
# Generator loss: 3.68358588, Discriminator loss: 0.36526242
# Epoch 35 of 200
# Generator loss: 3.92574477, Discriminator loss: 0.33401433
# Epoch 36 of 200
# Generator loss: 4.41510296, Discriminator loss: 0.31204858
# Epoch 37 of 200
# Generator loss: 3.75569487, Discriminator loss: 0.39238468
# Epoch 38 of 200
# Generator loss: 3.24085784, Discriminator loss: 0.46481526
# Epoch 39 of 200
# Generator loss: 3.59413528, Discriminator loss: 0.37654257
# Epoch 40 of 200
# Generator loss: 3.55200529, Discriminator loss: 0.38607547
# Epoch 41 of 200
# Generator loss: 3.80106258, Discriminator loss: 0.33319393
# Epoch 42 of 200
# Generator loss: 3.69518638, Discriminator loss: 0.37944540
# Epoch 43 of 200
# Generator loss: 3.52911496, Discriminator loss: 0.37556726
# Epoch 44 of 200
# Generator loss: 3.51765227, Discriminator loss: 0.40289429
# Epoch 45 of 200
# Generator loss: 3.45277882, Discriminator loss: 0.37020415
# Epoch 46 of 200
# Generator loss: 3.50205874, Discriminator loss: 0.38237157
# Epoch 47 of 200
# Generator loss: 3.24961925, Discriminator loss: 0.43186671
# Epoch 48 of 200
# Generator loss: 3.35108328, Discriminator loss: 0.41181841
# Epoch 49 of 200
# Generator loss: 3.22779703, Discriminator loss: 0.41573197
# Epoch 50 of 200
# Generator loss: 3.17208123, Discriminator loss: 0.44299769
# Epoch 51 of 200
# Generator loss: 3.13388848, Discriminator loss: 0.41060430
# Epoch 52 of 200
# Generator loss: 3.31323242, Discriminator loss: 0.42371419
# Epoch 53 of 200
# Generator loss: 3.22454691, Discriminator loss: 0.44121543
# Epoch 54 of 200
# Generator loss: 3.04075313, Discriminator loss: 0.47963646
# Epoch 55 of 200
# Generator loss: 3.03980350, Discriminator loss: 0.46647933
# Epoch 56 of 200
# Generator loss: 2.99745512, Discriminator loss: 0.51719201
# Epoch 57 of 200
# Generator loss: 3.07722616, Discriminator loss: 0.48978916
# Epoch 58 of 200
# Generator loss: 2.81689262, Discriminator loss: 0.50908190
# Epoch 59 of 200
# Generator loss: 2.73199654, Discriminator loss: 0.55340755
# Epoch 60 of 200
# Generator loss: 2.55979061, Discriminator loss: 0.58818513
# Epoch 61 of 200
# Generator loss: 2.40897751, Discriminator loss: 0.60022783
# Epoch 62 of 200
# Generator loss: 2.58602214, Discriminator loss: 0.56278884
# Epoch 63 of 200
# Generator loss: 2.59285688, Discriminator loss: 0.60087365
# Epoch 64 of 200
# Generator loss: 2.48731995, Discriminator loss: 0.61898077
# Epoch 65 of 200
# Generator loss: 2.40535831, Discriminator loss: 0.61028248
# Epoch 66 of 200
# Generator loss: 2.58736753, Discriminator loss: 0.59434229
# Epoch 67 of 200
# Generator loss: 2.48019528, Discriminator loss: 0.59372431
# Epoch 68 of 200
# Generator loss: 2.30890369, Discriminator loss: 0.64623713
# Epoch 69 of 200
# Generator loss: 2.43470311, Discriminator loss: 0.59863204
# Epoch 70 of 200
# Generator loss: 2.52286625, Discriminator loss: 0.61323857
# Epoch 71 of 200
# Generator loss: 2.44502831, Discriminator loss: 0.64013225
# Epoch 72 of 200
# Generator loss: 2.28499126, Discriminator loss: 0.64985430
# Epoch 73 of 200
# Generator loss: 2.35137606, Discriminator loss: 0.65044922
# Epoch 74 of 200
# Generator loss: 2.29667473, Discriminator loss: 0.64640522
# Epoch 75 of 200
# Generator loss: 2.38478684, Discriminator loss: 0.67743045
# Epoch 76 of 200
# Generator loss: 2.48403144, Discriminator loss: 0.61408728
# Epoch 77 of 200
# Generator loss: 2.53364348, Discriminator loss: 0.60293728
# Epoch 78 of 200
# Generator loss: 2.55942011, Discriminator loss: 0.63443696
# Epoch 79 of 200
# Generator loss: 2.38456225, Discriminator loss: 0.68419570
# Epoch 80 of 200
# Generator loss: 2.33450103, Discriminator loss: 0.68697929
# Epoch 81 of 200
# Generator loss: 2.33531737, Discriminator loss: 0.67473030
# Epoch 82 of 200
# Generator loss: 2.26237869, Discriminator loss: 0.68535882
# Epoch 83 of 200
# Generator loss: 2.28070498, Discriminator loss: 0.68279105
# Epoch 84 of 200
# Generator loss: 2.32227230, Discriminator loss: 0.70287353
# Epoch 85 of 200
# Generator loss: 2.29059076, Discriminator loss: 0.69301486
# Epoch 86 of 200
# Generator loss: 2.23233795, Discriminator loss: 0.70893574
# Epoch 87 of 200
# Generator loss: 2.19087744, Discriminator loss: 0.72994626
# Epoch 88 of 200
# Generator loss: 2.16655326, Discriminator loss: 0.76142162
# Epoch 89 of 200
# Generator loss: 2.06632447, Discriminator loss: 0.75944668
# Epoch 90 of 200
# Generator loss: 2.01519322, Discriminator loss: 0.77574050
# Epoch 91 of 200
# Generator loss: 2.02418780, Discriminator loss: 0.75246811
# Epoch 92 of 200
# Generator loss: 2.07135487, Discriminator loss: 0.77212352
# Epoch 93 of 200
# Generator loss: 2.05933881, Discriminator loss: 0.75491136
# Epoch 94 of 200
# Generator loss: 2.03542733, Discriminator loss: 0.75858343
# Epoch 95 of 200
# Generator loss: 1.99207270, Discriminator loss: 0.77059281
# Epoch 96 of 200
# Generator loss: 2.04870820, Discriminator loss: 0.77535117
# Epoch 97 of 200
# Generator loss: 2.07668781, Discriminator loss: 0.71972525
# Epoch 98 of 200
# Generator loss: 2.08492780, Discriminator loss: 0.73491323
# Epoch 99 of 200
# Generator loss: 2.09718990, Discriminator loss: 0.76263434
# Epoch 100 of 200
# Generator loss: 2.01060367, Discriminator loss: 0.76126295
# Epoch 101 of 200
# Generator loss: 2.00258064, Discriminator loss: 0.76974386
# Epoch 102 of 200
# Generator loss: 2.04073453, Discriminator loss: 0.76689929
# Epoch 103 of 200
# Generator loss: 2.02485108, Discriminator loss: 0.77342403
# Epoch 104 of 200
# Generator loss: 1.89606810, Discriminator loss: 0.80455393
# Epoch 105 of 200
# Generator loss: 1.87593305, Discriminator loss: 0.81428915
# Epoch 106 of 200
# Generator loss: 1.91178679, Discriminator loss: 0.83346313
# Epoch 107 of 200
# Generator loss: 1.94732940, Discriminator loss: 0.81774074
# Epoch 108 of 200
# Generator loss: 2.06230021, Discriminator loss: 0.75921059
# Epoch 109 of 200
# Generator loss: 1.90127051, Discriminator loss: 0.79943109
# Epoch 110 of 200
# Generator loss: 1.85801291, Discriminator loss: 0.79943973
# Epoch 111 of 200
# Generator loss: 1.94040310, Discriminator loss: 0.80670774
# Epoch 112 of 200
# Generator loss: 1.92345297, Discriminator loss: 0.83513021
# Epoch 113 of 200
# Generator loss: 1.95570362, Discriminator loss: 0.82119966
# Epoch 114 of 200
# Generator loss: 1.89965558, Discriminator loss: 0.83302069
# Epoch 115 of 200
# Generator loss: 1.86178088, Discriminator loss: 0.83775342
# Epoch 116 of 200
# Generator loss: 1.87205505, Discriminator loss: 0.83336443
# Epoch 117 of 200
# Generator loss: 1.88831115, Discriminator loss: 0.83573759
# Epoch 118 of 200
# Generator loss: 1.97733450, Discriminator loss: 0.81395578
# Epoch 119 of 200
# Generator loss: 1.91547716, Discriminator loss: 0.81427890
# Epoch 120 of 200
# Generator loss: 1.91261184, Discriminator loss: 0.81881183
# Epoch 121 of 200
# Generator loss: 1.95616519, Discriminator loss: 0.80207211
# Epoch 122 of 200
# Generator loss: 1.84485281, Discriminator loss: 0.83875608
# Epoch 123 of 200
# Generator loss: 1.83790600, Discriminator loss: 0.82771575
# Epoch 124 of 200
# Generator loss: 1.86443579, Discriminator loss: 0.81878430
# Epoch 125 of 200
# Generator loss: 1.83622622, Discriminator loss: 0.84145254
# Epoch 126 of 200
# Generator loss: 1.81640863, Discriminator loss: 0.86484915
# Epoch 127 of 200
# Generator loss: 1.73097837, Discriminator loss: 0.89158928
# Epoch 128 of 200
# Generator loss: 1.76209795, Discriminator loss: 0.86490142
# Epoch 129 of 200
# Generator loss: 1.77002287, Discriminator loss: 0.85448843
# Epoch 130 of 200
# Generator loss: 1.76650822, Discriminator loss: 0.87782258
# Epoch 131 of 200
# Generator loss: 1.68401182, Discriminator loss: 0.89859408
# Epoch 132 of 200
# Generator loss: 1.73783827, Discriminator loss: 0.87387949
# Epoch 133 of 200
# Generator loss: 1.71422410, Discriminator loss: 0.87342799
# Epoch 134 of 200
# Generator loss: 1.64804149, Discriminator loss: 0.92056519
# Epoch 135 of 200
# Generator loss: 1.61141527, Discriminator loss: 0.92979008
# Epoch 136 of 200
# Generator loss: 1.69294059, Discriminator loss: 0.91300446
# Epoch 137 of 200
# Generator loss: 1.65581107, Discriminator loss: 0.91610688
# Epoch 138 of 200
# Generator loss: 1.57897317, Discriminator loss: 0.93938726
# Epoch 139 of 200
# Generator loss: 1.58121490, Discriminator loss: 0.94962001
# Epoch 140 of 200
# Generator loss: 1.57282543, Discriminator loss: 0.94817710
# Epoch 141 of 200
# Generator loss: 1.59413695, Discriminator loss: 0.93474984
# Epoch 142 of 200
# Generator loss: 1.58950579, Discriminator loss: 0.95931739
# Epoch 143 of 200
# Generator loss: 1.61547637, Discriminator loss: 0.93759090
# Epoch 144 of 200
# Generator loss: 1.59741724, Discriminator loss: 0.91640133
# Epoch 145 of 200
# Generator loss: 1.51326072, Discriminator loss: 0.95270228
# Epoch 146 of 200
# Generator loss: 1.50204527, Discriminator loss: 0.97235781
# Epoch 147 of 200
# Generator loss: 1.56929529, Discriminator loss: 0.97289711
# Epoch 148 of 200
# Generator loss: 1.50815332, Discriminator loss: 0.97245699
# Epoch 149 of 200
# Generator loss: 1.51177680, Discriminator loss: 0.97954369
# Epoch 150 of 200
# Generator loss: 1.44339359, Discriminator loss: 0.99755394
# Epoch 151 of 200
# Generator loss: 1.50592887, Discriminator loss: 0.97468126
# Epoch 152 of 200
# Generator loss: 1.51354039, Discriminator loss: 0.97676194
# Epoch 153 of 200
# Generator loss: 1.50597048, Discriminator loss: 0.97349399
# Epoch 154 of 200
# Generator loss: 1.49245226, Discriminator loss: 0.99896818
# Epoch 155 of 200
# Generator loss: 1.55209625, Discriminator loss: 0.96801752
# Epoch 156 of 200
# Generator loss: 1.42093790, Discriminator loss: 1.00295031
# Epoch 157 of 200
# Generator loss: 1.51278889, Discriminator loss: 0.98672992
# Epoch 158 of 200
# Generator loss: 1.47138405, Discriminator loss: 1.00308967
# Epoch 159 of 200
# Generator loss: 1.50952172, Discriminator loss: 0.97552222
# Epoch 160 of 200
# Generator loss: 1.51928186, Discriminator loss: 0.97501165
# Epoch 161 of 200
# Generator loss: 1.50132823, Discriminator loss: 0.97586066
# Epoch 162 of 200
# Generator loss: 1.48539352, Discriminator loss: 0.99768448
# Epoch 163 of 200
# Generator loss: 1.47062743, Discriminator loss: 0.98793089
# Epoch 164 of 200
# Generator loss: 1.45100570, Discriminator loss: 1.01886988
# Epoch 165 of 200
# Generator loss: 1.46368635, Discriminator loss: 1.01012135
# Epoch 166 of 200
# Generator loss: 1.34086788, Discriminator loss: 1.04900265
# Epoch 167 of 200
# Generator loss: 1.34982979, Discriminator loss: 1.05677938
# Epoch 168 of 200
# Generator loss: 1.33423877, Discriminator loss: 1.05083227
# Epoch 169 of 200
# Generator loss: 1.34035385, Discriminator loss: 1.05562687
# Epoch 170 of 200
# Generator loss: 1.38325250, Discriminator loss: 1.03436649
# Epoch 171 of 200
# Generator loss: 1.31622791, Discriminator loss: 1.05499792
# Epoch 172 of 200
# Generator loss: 1.37680554, Discriminator loss: 1.04261351
# Epoch 173 of 200
# Generator loss: 1.32548440, Discriminator loss: 1.06495905
# Epoch 174 of 200
# Generator loss: 1.34986162, Discriminator loss: 1.05977070
# Epoch 175 of 200
# Generator loss: 1.36009884, Discriminator loss: 1.04313743
# Epoch 176 of 200
# Generator loss: 1.34904814, Discriminator loss: 1.05456269
# Epoch 177 of 200
# Generator loss: 1.34146178, Discriminator loss: 1.06597877
# Epoch 178 of 200
# Generator loss: 1.32828259, Discriminator loss: 1.05004704
# Epoch 179 of 200
# Generator loss: 1.33663857, Discriminator loss: 1.05367076
# Epoch 180 of 200
# Generator loss: 1.36802578, Discriminator loss: 1.03865719
# Epoch 181 of 200
# Generator loss: 1.34480715, Discriminator loss: 1.04955363
# Epoch 182 of 200
# Generator loss: 1.34473777, Discriminator loss: 1.06199920
# Epoch 183 of 200
# Generator loss: 1.29540908, Discriminator loss: 1.06445253
# Epoch 184 of 200
# Generator loss: 1.34512496, Discriminator loss: 1.06103539
# Epoch 185 of 200
# Generator loss: 1.32138228, Discriminator loss: 1.06872284
# Epoch 186 of 200
# Generator loss: 1.31803548, Discriminator loss: 1.07177508
# Epoch 187 of 200
# Generator loss: 1.33651185, Discriminator loss: 1.07466221
# Epoch 188 of 200
# Generator loss: 1.30932319, Discriminator loss: 1.05944932
# Epoch 189 of 200
# Generator loss: 1.37065375, Discriminator loss: 1.04856741
# Epoch 190 of 200
# Generator loss: 1.35822523, Discriminator loss: 1.03735721
# Epoch 191 of 200
# Generator loss: 1.33408689, Discriminator loss: 1.05342615
# Epoch 192 of 200
# Generator loss: 1.28812492, Discriminator loss: 1.07302165
# Epoch 193 of 200
# Generator loss: 1.29738140, Discriminator loss: 1.06730330
# Epoch 194 of 200
# Generator loss: 1.34077775, Discriminator loss: 1.06089485
# Epoch 195 of 200
# Generator loss: 1.29843438, Discriminator loss: 1.08258641
# Epoch 196 of 200
# Generator loss: 1.31241369, Discriminator loss: 1.07023931
# Epoch 197 of 200
# Generator loss: 1.30264890, Discriminator loss: 1.06393659
# Epoch 198 of 200
# Generator loss: 1.31977534, Discriminator loss: 1.05492294
# Epoch 199 of 200
# Generator loss: 1.29613936, Discriminator loss: 1.08308017

# %%
plt.figure()
losses_g = [fl.item() for fl in losses_g]
plt.plot(losses_g, label="Generator Loss")
losses_d = [f2.item() for f2 in losses_d]
plt.plot(losses_d, label="Discriminator Loss")
plt.legend()

# %%
fake_images = generator(torch.randn(b_size, nz).to(device))
for i in range(10):
    fake_images_img = np.reshape(fake_images.data.cpu().numpy()[i], (28, 28))
    plt.imshow(fake_images_img, cmap="gray")
    plt.savefig("../pytorch/data/fake_images_img" + str(i) + ".png")
    plt.show()
